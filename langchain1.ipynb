# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakGupta345/PytorchLearning/blob/main/langchain1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# !pip install -qU langchain-groq
# !pip install langchain
# Out:
# hello world
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --quite

# %%
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

load_dotenv()
# Out:
# False

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %%
llm = ChatGroq(
    model="qwen/qwen3-32b",
    temperature=0,
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
prompts = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant. answer the questions"),
        ("human", "question: {input}"),
    ]
)

# %%
output_parser = StrOutputParser()
chain = prompts | llm | output_parser

# %%
question = input("Enter your question")
response = chain.invoke({"input": question})
print(response)
# Out:
# Enter your questionwho is elon musk
# Elon Musk is a South African-born entrepreneur, engineer, and business magnate known for his visionary approach to technology and innovation. Born on June 28, 1971, in Pretoria, South Africa, he is the founder, CEO, or co-founder of several high-profile companies that aim to address global challenges and push the boundaries of science and engineering.
#
# ### Key Highlights:
# 1. **Early Life and Education**:
#    Musk studied physics and economics at the University of Pennsylvania. He later moved to the U.S., where he began his entrepreneurial journey.
#
# 2. **Early Ventures**:
#    - Co-founded **Zip2**, a web software company, which was sold to Compaq in 1999.
#    - Co-founded **PayPal**, a digital payment platform, which eBay acquired in 2002.
#
# 3. **Major Companies**:
#    - **Tesla, Inc.**: A leader in electric vehicles (EVs) and renewable energy solutions (e.g., solar panels, battery storage).
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakGupta345/PytorchLearning/blob/main/Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pytorch autograd
print("Hello world")
# Out:
# Hello word;

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2
print(y)
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(12.)

# %%
#examples 2
x = torch.rand(3,requires_grad=True)
y = x**2
z = torch.sin(y)

# %%
x,y,z
# Out:
# (tensor([8.5750e-01, 4.2224e-04, 6.1753e-01], requires_grad=True),
#  tensor([7.3530e-01, 1.7829e-07, 3.8135e-01], grad_fn=<PowBackward0>),
#  tensor([6.7081e-01, 1.7829e-07, 3.7217e-01], grad_fn=<SinBackward0>))

# %%
print(z)
# Out:
# tensor([0.2048, 0.8070, 0.8255], grad_fn=<SinBackward0>)

# %%
print(y)
# Out:
# tensor([0.2063, 0.9390, 0.9711], grad_fn=<PowBackward0>)

# %%
z.backwward()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2883183726.py in <cell line: 0>()
# ----> 1 z.backwward()
#
# AttributeError: 'Tensor' object has no attribute 'backwward'

# %%
x.grad

# %%
print(x.grad)
# Out:
# None

# %%
#Example 3

x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w*x+b

# %%
y_pred = torch.sigmoid(z)
print(y_pred)
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = torch.binary_cross_entropy_with_logits(y_pred,y)
loss
# Out:
# tensor(1.3124, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(0.0060)
# tensor(0.0009)

# %%
x = torch.tensor([1,2,3],dtype=torch.float32, requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
print(x.grad)
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
#clear gradient
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2

# %%
y.backward()

# %%
print(x.grad)
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
z = x.detach()

# %%
with torch.no_grad():
    y = x**2
